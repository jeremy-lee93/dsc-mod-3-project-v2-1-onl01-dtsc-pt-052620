# %% [markdown]
# ## Final Project Submission
#
# Please fill out:
# * Student name:
# * Student pace: self paced / part time / full time
# * Scheduled project review date/time:
# * Instructor name:
# * Blog post URL:

# %%
# Your code here - remember to use markdown cells for comments as well!
#2016-2017
#2017-2018
#2018-2019
import pandas as pd
import re
import requests
from nba_stats_tracking import tracking
import time
df = pd.read_csv('2017-2018_player_per100poss.csv')
df2 = pd.read_csv('2017-2018_player_adv.csv')
df3 = pd.read_csv('2017-2018_player_shooting_stats.csv', header = [0, 1])

# %%
df.head()
# Out:
#    Rk                   Player Pos  Age   Tm   G  GS    MP   FG   FGA  ...  \
# 0   1   Álex Abrines\abrinal01  SG   24  OKC  75   8  1134  5.0  12.7  ...
# 1   2       Quincy Acy\acyqu01  PF   27  BRK  70   8  1359  4.6  13.0  ...
# 2   3   Steven Adams\adamsst01   C   24  OKC  76  76  2487  8.9  14.2  ...
# 3   4    Bam Adebayo\adebaba01   C   20  MIA  69  19  1368  6.4  12.5  ...
# 4   5  Arron Afflalo\afflaar01  SG   32  ORL  53   3   682  4.7  11.6  ...
#
#     TRB  AST  STL  BLK  TOV   PF   PTS  Unnamed: 29   ORtg  DRtg
# 0   5.0  1.2  1.7  0.4  1.1  5.4  15.4          NaN  116.0   110
# 1   9.2  2.0  1.2  1.0  2.1  5.3  14.7          NaN   99.0   110
# 2  13.7  1.8  1.8  1.6  2.6  4.3  21.1          NaN  125.0   107
# 3  14.0  3.7  1.2  1.5  2.4  5.1  17.5          NaN  116.0   105
# 4   4.7  2.2  0.3  0.6  1.5  4.0  12.8          NaN   98.0   115
#
# [5 rows x 32 columns]

# %%
df.columns
# Out:
# Index(['Rk', 'Player', 'Pos', 'Age', 'Tm', 'G', 'GS', 'MP', 'FG', 'FGA', 'FG%',
#        '3P', '3PA', '3P%', '2P', '2PA', '2P%', 'FT', 'FTA', 'FT%', 'ORB',
#        'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS', 'Unnamed: 29',
#        'ORtg', 'DRtg'],
#       dtype='object')

# %%
df2.head()
# Out:
#    Rk                   Player Pos  Age   Tm   G    MP   PER    TS%   3PAr  \
# 0   1   Álex Abrines\abrinal01  SG   24  OKC  75  1134   9.0  0.567  0.759
# 1   2       Quincy Acy\acyqu01  PF   27  BRK  70  1359   8.2  0.525  0.800
# 2   3   Steven Adams\adamsst01   C   24  OKC  76  2487  20.6  0.630  0.003
# 3   4    Bam Adebayo\adebaba01   C   20  MIA  69  1368  15.7  0.570  0.021
# 4   5  Arron Afflalo\afflaar01  SG   32  ORL  53   682   5.8  0.516  0.432
#
#    ...  Unnamed: 19  OWS  DWS   WS  WS/48  Unnamed: 24  OBPM  DBPM  BPM  VORP
# 0  ...          NaN  1.3  1.0  2.2  0.094          NaN  -1.9   0.4 -1.5   0.1
# 1  ...          NaN -0.1  1.1  1.0  0.036          NaN  -2.6   0.1 -2.5  -0.2
# 2  ...          NaN  6.7  3.0  9.7  0.187          NaN   1.7  -0.6  1.1   2.0
# 3  ...          NaN  2.3  1.9  4.2  0.148          NaN  -1.1   0.7 -0.4   0.6
# 4  ...          NaN -0.1  0.2  0.1  0.009          NaN  -3.8  -1.5 -5.4  -0.6
#
# [5 rows x 29 columns]

# %%
df2.columns
# Out:
# Index(['Rk', 'Player', 'Pos', 'Age', 'Tm', 'G', 'MP', 'PER', 'TS%', '3PAr',
#        'FTr', 'ORB%', 'DRB%', 'TRB%', 'AST%', 'STL%', 'BLK%', 'TOV%', 'USG%',
#        'Unnamed: 19', 'OWS', 'DWS', 'WS', 'WS/48', 'Unnamed: 24', 'OBPM',
#        'DBPM', 'BPM', 'VORP'],
#       dtype='object')

# %%
df3.head()
# Out:
#   Unnamed: 0_level_0       Unnamed: 1_level_0 Unnamed: 2_level_0  \
#                   Rk                   Player                Pos
# 0                  1   Álex Abrines\abrinal01                 SG
# 1                  2       Quincy Acy\acyqu01                 PF
# 2                  3   Steven Adams\adamsst01                  C
# 3                  4    Bam Adebayo\adebaba01                  C
# 4                  5  Arron Afflalo\afflaar01                 SG
#
#   Unnamed: 3_level_0 Unnamed: 4_level_0 Unnamed: 5_level_0 Unnamed: 6_level_0  \
#                  Age                 Tm                  G                 MP
# 0                 24                OKC                 75               1134
# 1                 27                BRK                 70               1359
# 2                 24                OKC                 76               2487
# 3                 20                MIA                 69               1368
# 4                 32                ORL                 53                682
#
#   Unnamed: 7_level_0 Unnamed: 8_level_0 Unnamed: 9_level_0  ... % of FG Ast'd  \
#                  FG%              Dist. Unnamed: 9_level_1  ...            3P
# 0              0.395               20.3                NaN  ...         1.000
# 1              0.356               20.7                NaN  ...         0.990
# 2              0.629                2.6                NaN  ...           NaN
# 3              0.512                4.3                NaN  ...           NaN
# 4              0.401               17.1                NaN  ...         0.926
#
#   Unnamed: 26_level_0  Dunks      Unnamed: 29_level_0 Corner 3s         \
#   Unnamed: 26_level_1   %FGA    # Unnamed: 29_level_1      %3PA    3P%
# 0                 NaN  0.034    9                 NaN     0.253  0.375
# 1                 NaN  0.036    9                 NaN     0.305  0.404
# 2                 NaN  0.242  150                 NaN     0.000    NaN
# 3                 NaN  0.294   91                 NaN     0.000    NaN
# 4                 NaN  0.000    0                 NaN     0.414  0.276
#
#   Unnamed: 32_level_0 Heaves
#   Unnamed: 32_level_1   Att.  #
# 0                 NaN      1  0
# 1                 NaN      0  0
# 2                 NaN      2  0
# 3                 NaN      4  0
# 4                 NaN      0  0
#
# [5 rows x 35 columns]

# %%
df3.columns
# Out:
# MultiIndex([(  'Unnamed: 0_level_0',                  'Rk'),
#             (  'Unnamed: 1_level_0',              'Player'),
#             (  'Unnamed: 2_level_0',                 'Pos'),
#             (  'Unnamed: 3_level_0',                 'Age'),
#             (  'Unnamed: 4_level_0',                  'Tm'),
#             (  'Unnamed: 5_level_0',                   'G'),
#             (  'Unnamed: 6_level_0',                  'MP'),
#             (  'Unnamed: 7_level_0',                 'FG%'),
#             (  'Unnamed: 8_level_0',               'Dist.'),
#             (  'Unnamed: 9_level_0',  'Unnamed: 9_level_1'),
#             ('% of FGA by Distance',                  '2P'),
#             ('% of FGA by Distance',                 '0-3'),
#             ('% of FGA by Distance',                '3-10'),
#             ('% of FGA by Distance',               '10-16'),
#             ('% of FGA by Distance',               '16-3P'),
#             ('% of FGA by Distance',                  '3P'),
#             ( 'Unnamed: 16_level_0', 'Unnamed: 16_level_1'),
#             (     'FG% by Distance',                  '2P'),
#             (     'FG% by Distance',                 '0-3'),
#             (     'FG% by Distance',                '3-10'),
#             (     'FG% by Distance',               '10-16'),
#             (     'FG% by Distance',               '16-3P'),
#             (     'FG% by Distance',                  '3P'),
#             ( 'Unnamed: 23_level_0', 'Unnamed: 23_level_1'),
#             (       '% of FG Ast'd',                  '2P'),
#             (       '% of FG Ast'd',                  '3P'),
#             ( 'Unnamed: 26_level_0', 'Unnamed: 26_level_1'),
#             (               'Dunks',                '%FGA'),
#             (               'Dunks',                   '#'),
#             ( 'Unnamed: 29_level_0', 'Unnamed: 29_level_1'),
#             (           'Corner 3s',                '%3PA'),
#             (           'Corner 3s',                 '3P%'),
#             ( 'Unnamed: 32_level_0', 'Unnamed: 32_level_1'),
#             (              'Heaves',                'Att.'),
#             (              'Heaves',                   '#')],
#            )

# %%
#Creating functions to perform simple, preliminary cleaning
def reformat_standard_stats(dataframe):
    """Takes in a dataframe of player stats from Basketball Reference(either per game or per 100 possessions) 
    and removes columns that will not be necessary for data analysis or modeling."""
    df_new = dataframe.drop(columns=['Rk', 'Unnamed: 29']) #remove unncessary columns not relevant to EDA
    
    return df_new

def reformat_adv_stats(dataframe):
    """Takes in a dataframe of advanced player stats from Basketball Reference and removes columns that 
    will not be necessary for data analysis or modeling. We will also drop columns that are common with
    columns in the standard statistics dataframe."""
    df_new = dataframe.drop(columns=['Rk', 'Player', 'Pos', 'Age', 'Tm', 'G', 'MP', 
                                     'Unnamed: 19', 'Unnamed: 24'])
    
    return df_new

# %%
def join_dataframes(stand_df, adv_df, shooting_stats_df):
    """Joins standard and advanced dataframes from Basketball Reference into a singular dataframes.  Appends 
    selected columns from the shooting statistics dataframe.
    
    stand_df: A dataframe with standard player statistics from Basketball Reference. For example see this
    website: https://www.basketball-reference.com/leagues/NBA_2018_per_poss.html
    
    adv_df: A dataframe with advanced player statistics from Basketball Reference. For example see this 
    website: https://www.basketball-reference.com/leagues/NBA_2018_advanced.html
    
    shooting_stats_df: A dataframe with player shooting statistics from Basketball Reference. For example
    see this website: https://www.basketball-reference.com/leagues/NBA_2018_shooting.html
    
    year_range: The year range for an NBA season."""
    
    df_std_reformat = reformat_standard_stats(stand_df)
    df_adv_reformat = reformat_adv_stats(adv_df)
    
    df_joined_two = df_std_reformat.join(df_adv_reformat) #join standard and advanced player stats dataframes
    
    #creating new columns with data from shooting statistics dataframe
    df_joined_two['pct_of_FGA_twos'] = shooting_stats_df['% of FGA by Distance']['2P']
    df_joined_two['pct_of_FGA_threes'] = shooting_stats_df['% of FGA by Distance']['3P']
    df_joined_two['two_pt_fg_pct'] = shooting_stats_df['FG% by Distance']['2P']
    df_joined_two['three_pt_fg_pct'] = shooting_stats_df['FG% by Distance']['3P']
    
    df_final = df_joined_two
    
    return df_final

# %%
#check to make sure dataframes from the same year are the same length before running functions
len(df) == len(df2) == len(df3)
# Out:
# True

# %%
bballref_1718_df = join_dataframes(df, df2, df3)
bballref_1718_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 664 entries, 0 to 663
# Data columns (total 54 columns):
# Player               664 non-null object
# Pos                  664 non-null object
# Age                  664 non-null int64
# Tm                   664 non-null object
# G                    664 non-null int64
# GS                   664 non-null int64
# MP                   664 non-null int64
# FG                   664 non-null float64
# FGA                  664 non-null float64
# FG%                  660 non-null float64
# 3P                   664 non-null float64
# 3PA                  664 non-null float64
# 3P%                  599 non-null float64
# 2P                   664 non-null float64
# 2PA                  664 non-null float64
# 2P%                  646 non-null float64
# FT                   664 non-null float64
# FTA                  664 non-null float64
# FT%                  606 non-null float64
# ORB                  664 non-null float64
# DRB                  664 non-null float64
# TRB                  664 non-null float64
# AST                  664 non-null float64
# STL                  664 non-null float64
# BLK                  664 non-null float64
# TOV                  664 non-null float64
# PF                   664 non-null float64
# PTS                  664 non-null float64
# ORtg                 662 non-null float64
# DRtg                 664 non-null int64
# PER                  664 non-null float64
# TS%                  660 non-null float64
# 3PAr                 660 non-null float64
# FTr                  660 non-null float64
# ORB%                 664 non-null float64
# DRB%                 664 non-null float64
# TRB%                 664 non-null float64
# AST%                 664 non-null float64
# STL%                 664 non-null float64
# BLK%                 664 non-null float64
# TOV%                 660 non-null float64
# USG%                 664 non-null float64
# OWS                  664 non-null float64
# DWS                  664 non-null float64
# WS                   664 non-null float64
# WS/48                664 non-null float64
# OBPM                 664 non-null float64
# DBPM                 664 non-null float64
# BPM                  664 non-null float64
# VORP                 664 non-null float64
# pct_of_FGA_twos      660 non-null float64
# pct_of_FGA_threes    660 non-null float64
# two_pt_fg_pct        646 non-null float64
# three_pt_fg_pct      599 non-null float64
# dtypes: float64(46), int64(5), object(3)
# memory usage: 280.2+ KB

# %%
#Gathering Tracking Data from stats.nba.com via nba_tracking_stats api 
#select drives, CatchShoot, Passing, Possessions, SpeedDistance, PullUpShot

# %%
#preview statistics related to drives to the basket

stat_measure = 'Drives'
seasons = ['2018-19']
season_types = ['Regular Season']
entity_type = 'player'

stats, league_totals = tracking.aggregate_full_season_tracking_stats_for_seasons(
    stat_measure,
    seasons,
    season_types,
    entity_type)

    
    
pd.DataFrame(stats)
# Out:
#      PLAYER_ID      PLAYER_NAME     TEAM_ID TEAM_ABBREVIATION     MIN  DRIVES  \
# 0       203932     Aaron Gordon  1610612753               ORL  2567.0     466
# 1      1628988    Aaron Holiday  1610612754               IND   646.0     180
# 2      1627846      Abdel Nader  1610612760               OKC   686.0     130
# 3       201143       Al Horford  1610612738               BOS  1973.0     110
# 4       202329  Al-Farouq Aminu  1610612757               POR  2292.0     222
# ..         ...              ...         ...               ...     ...     ...
# 525     203897      Zach LaVine  1610612741               CHI  2130.0     841
# 526    1629155      Zach Lofton  1610612765               DET     4.0       1
# 527       2585    Zaza Pachulia  1610612765               DET   878.0      26
# 528    1629015     Zhaire Smith  1610612755               PHI   111.0      14
# 529    1627753          Zhou Qi  1610612745               HOU     1.0       0
#
#      DRIVE_FGM  DRIVE_FGA  DRIVE_FTM  DRIVE_FTA  DRIVE_PTS  DRIVE_PASSES  \
# 0           88        205         58         82        243           160
# 1           30         71          9         10         71            91
# 2           36         71          9         14         83            42
# 3           28         50         15         17         72            42
# 4           53        114         35         41        144            56
# ..         ...        ...        ...        ...        ...           ...
# 525        207        417        160        197        590           247
# 526          0          0          0          0          0             1
# 527          6          9          6         10         18            10
# 528          3          6          1          2          7             4
# 529          0          0          0          0          0             0
#
#      DRIVE_AST  DRIVE_TOV  DRIVE_PF
# 0           48         48        40
# 1           25          7         5
# 2           11          9         5
# 3           13          9         7
# 4           26         20        20
# ..         ...        ...       ...
# 525         52         60        95
# 526          0          0         0
# 527          1          1         5
# 528          0          2         1
# 529          0          0         0
#
# [530 rows x 15 columns]

# %%
#preview statistics related to catch and shoot attempts
stat_measure = 'CatchShoot'
seasons = ['2017-18']
season_types = ['Regular Season']
entity_type = 'player'
stats, league_totals = tracking.aggregate_full_season_tracking_stats_for_seasons(
    stat_measure,
    seasons,
    season_types,
    entity_type
)
pd.DataFrame(stats)
# Out:
#      PLAYER_ID     PLAYER_NAME     TEAM_ID TEAM_ABBREVIATION     MIN  \
# 0       201166    Aaron Brooks  1610612750               MIN   189.0
# 1       203932    Aaron Gordon  1610612753               ORL  1909.0
# 2      1626151  Aaron Harrison  1610612742               DAL   233.0
# 3      1628935   Aaron Jackson  1610612745               HOU    35.0
# 4      1627846     Abdel Nader  1610612738               BOS   522.0
# ..         ...             ...         ...               ...     ...
# 535    1628380    Zach Collins  1610612757               POR  1045.0
# 536     203897     Zach LaVine  1610612741               CHI   656.0
# 537       2216   Zach Randolph  1610612758               SAC  1508.0
# 538       2585   Zaza Pachulia  1610612744               GSW   972.0
# 539    1627753         Zhou Qi  1610612745               HOU   124.0
#
#      CATCH_SHOOT_FGM  CATCH_SHOOT_FGA  CATCH_SHOOT_PTS  CATCH_SHOOT_FG3M  \
# 0                  8               15               24               8.0
# 1                100              265              289              89.0
# 2                  8               37               24               8.0
# 3                  0                2                0               0.0
# 4                 23               65               68              22.0
# ..               ...              ...              ...               ...
# 535               45              137              125              35.0
# 536               13               40               39              13.0
# 537               78              225              206              50.0
# 538               17               40               34               0.0
# 539                2               19                6               2.0
#
#      CATCH_SHOOT_FG3A
# 0                14.0
# 1               227.0
# 2                37.0
# 3                 2.0
# 4                63.0
# ..                ...
# 535             109.0
# 536              40.0
# 537             143.0
# 538               1.0
# 539              19.0
#
# [540 rows x 10 columns]

# %%
#preview statistics related to drives to how often a player has the ball 
stat_measure = 'Possessions'
seasons = ['2018-19']
season_types = ['Regular Season']
entity_type = 'player'
stats, league_totals = tracking.aggregate_full_season_tracking_stats_for_seasons(
    stat_measure,
    seasons,
    season_types,
    entity_type
)
pd.DataFrame(stats)
# Out:
#      PLAYER_ID      PLAYER_NAME     TEAM_ID TEAM_ABBREVIATION     MIN  POINTS  \
# 0       203932     Aaron Gordon  1610612753               ORL  2567.0    1230
# 1      1628988    Aaron Holiday  1610612754               IND   646.0     294
# 2      1627846      Abdel Nader  1610612760               OKC   686.0     238
# 3       201143       Al Horford  1610612738               BOS  1973.0     925
# 4       202329  Al-Farouq Aminu  1610612757               POR  2292.0     760
# ..         ...              ...         ...               ...     ...     ...
# 525     203897      Zach LaVine  1610612741               CHI  2130.0    1469
# 526    1629155      Zach Lofton  1610612765               DET     4.0       0
# 527       2585    Zaza Pachulia  1610612765               DET   878.0     267
# 528    1629015     Zhaire Smith  1610612755               PHI   111.0      40
# 529    1627753          Zhou Qi  1610612745               HOU     1.0       2
#
#      TOUCHES  FRONT_CT_TOUCHES  TIME_OF_POSS  ELBOW_TOUCHES  POST_TOUCHES  \
# 0       4142              2485         180.8            198           219
# 1       1149               523          78.4              9             0
# 2        615               391          22.4              8             0
# 3       3878              2542         115.3            279           254
# 4       2914              1365          92.6             88            21
# ..       ...               ...           ...            ...           ...
# 525     3900              2257         297.1             50            28
# 526        5                 3           0.2              0             0
# 527     1417               868          43.3            166            69
# 528      121                93           3.6              4             0
# 529        1                 1           0.0              0             0
#
#      PAINT_TOUCHES
# 0              328
# 1                6
# 2               15
# 3              351
# 4              197
# ..             ...
# 525             86
# 526              0
# 527            236
# 528              6
# 529              1
#
# [530 rows x 12 columns]

# %%
#preview statistics related to pull up shots
stat_measure = 'PullUpShot'
seasons = ['2018-19']
season_types = ['Regular Season']
entity_type = 'player'
stats, league_totals = tracking.aggregate_full_season_tracking_stats_for_seasons(
    stat_measure,
    seasons,
    season_types,
    entity_type
)
pd.DataFrame(stats)
# Out:
#      PLAYER_ID      PLAYER_NAME     TEAM_ID TEAM_ABBREVIATION     MIN  \
# 0       203932     Aaron Gordon  1610612753               ORL  2633.0
# 1      1628988    Aaron Holiday  1610612754               IND   646.0
# 2      1627846      Abdel Nader  1610612760               OKC   694.0
# 3       201143       Al Horford  1610612738               BOS  1973.0
# 4       202329  Al-Farouq Aminu  1610612757               POR  2292.0
# ..         ...              ...         ...               ...     ...
# 525     203897      Zach LaVine  1610612741               CHI  2171.0
# 526    1629155      Zach Lofton  1610612765               DET     4.0
# 527       2585    Zaza Pachulia  1610612765               DET   878.0
# 528    1629015     Zhaire Smith  1610612755               PHI   111.0
# 529    1627753          Zhou Qi  1610612745               HOU     1.0
#
#      PULL_UP_FGM  PULL_UP_FGA  PULL_UP_PTS  PULL_UP_FG3M  PULL_UP_FG3A
# 0             96          265          222          30.0          93.0
# 1             44          130          106          18.0          61.0
# 2              4           13           10           2.0           5.0
# 3             22           48           44           0.0           0.0
# 4              7           41           16           2.0          14.0
# ..           ...          ...          ...           ...           ...
# 525          144          403          360          72.0         195.0
# 526            0            0            0           0.0           0.0
# 527            4           13            8           0.0           3.0
# 528            3            8            8           2.0           4.0
# 529            0            0            0           NaN           NaN
#
# [530 rows x 10 columns]

# %%
#preview statistics related to speed and distance traveled for each player
stat_measure = 'SpeedDistance'
seasons = ['2018-19']
season_types = ['Regular Season']
entity_type = 'player'
stats, league_totals = tracking.aggregate_full_season_tracking_stats_for_seasons(
    stat_measure,
    seasons,
    season_types,
    entity_type
)
pd.DataFrame(stats)
# Out:
#      PLAYER_ID      PLAYER_NAME     TEAM_ID TEAM_ABBREVIATION     MIN  \
# 0       203932     Aaron Gordon  1610612753               ORL  2567.0
# 1      1628988    Aaron Holiday  1610612754               IND   646.0
# 2      1627846      Abdel Nader  1610612760               OKC   686.0
# 3       201143       Al Horford  1610612738               BOS  1973.0
# 4       202329  Al-Farouq Aminu  1610612757               POR  2292.0
# ..         ...              ...         ...               ...     ...
# 525     203897      Zach LaVine  1610612741               CHI  2130.0
# 526    1629155      Zach Lofton  1610612765               DET     4.0
# 527       2585    Zaza Pachulia  1610612765               DET   878.0
# 528    1629015     Zhaire Smith  1610612755               PHI   111.0
# 529    1627753          Zhou Qi  1610612745               HOU     1.0
#
#      DIST_FEET  DIST_MILES  DIST_MILES_OFF  DIST_MILES_DEF
# 0    1026628.0       194.4           109.5            84.9
# 1     266857.0        50.5            26.2            24.3
# 2     292756.0        55.4            28.2            27.3
# 3     733629.0       138.9            73.8            65.2
# 4     915800.0       173.4            95.4            78.0
# ..         ...         ...             ...             ...
# 525   881579.0       167.0            91.6            75.4
# 526     1474.0         0.3             0.1             0.1
# 527   335080.0        63.5            34.6            28.8
# 528    47651.0         9.0             5.0             4.0
# 529      385.0         0.1             0.0             0.0
#
# [530 rows x 9 columns]

# %%
def create_tracking_dataframes(season_type, year, entity):
    
    """This function uses the NBA Tracking API to collect various tracking data and combines the data
    into a single dataframe. This function collects information from the following tracking statistics:
    
    -Drives
    -Catch and Shoot
    -Possessions
    -Pull Up Shots
    -Speed and Distance
    
    Documentation on the API can be found at:
    
    https://nba-stats-tracking.readthedocs.io/en/latest/source/quickstart.html#
    
    season_type: Can be Regular Season or Playoffs. Needs to be a string.
    
    year: The year for which tracking data will be collected. Should be a string formatted
    like XXXX-XX (i.e. 2017-18).
    
    entity_type: Whether you would like to look at team or player statistics. Should be a string."""
    
    stats_to_track = ['Drives', 'CatchShoot', 'Possessions', 'PullUpShot', 'SpeedDistance']
    
    tracking_stats_list = []
    
    for stat in stats_to_track:
        measurable, league_stats = tracking.aggregate_full_season_tracking_stats_for_seasons(
            stat, #type of tracking data to collect
            [year], #specific season 
            [season_type], #regular season stats will be collected
            entity #player statistics will be collected
        ) 
        
        tracking_stats_list.append(measurable)
        time.sleep(3)
    
    #Create a dataframe for each type of stat
    drives_df = pd.DataFrame(tracking_stats_list[0])       #Drives to the basket
    catch_shoot_df = pd.DataFrame(tracking_stats_list[1])  #Catch and shoot
    poss_df = pd.DataFrame(tracking_stats_list[2])         #Number of touches
    pullup_df = pd.DataFrame(tracking_stats_list[3])       #Pull Up Shots
    speed_dist_df = pd.DataFrame(tracking_stats_list[4])   #Speed and Distance Metrics
    
    #Create a new dataframe combining pertinent columns from each type of tracking statistic
    tracking_combined_df = pd.DataFrame([])
    
    #select columns from drives_df
    if entity_type == 'player':
        tracking_combined_df['PLAYER_ID'] = drives_df['PLAYER_ID']
        tracking_combined_df['PLAYER_NAME'] = drives_df['PLAYER_NAME']
        
    tracking_combined_df['TEAM_ID'] = drives_df['TEAM_ID']
    tracking_combined_df['TEAM_ABBR'] = drives_df['TEAM_ABBREVIATION']
    tracking_combined_df['DRIVES'] = drives_df['DRIVES']
    tracking_combined_df['DRIVE_FGM'] = drives_df['DRIVE_FGM']
    tracking_combined_df['DRIVE_FGA'] = drives_df['DRIVE_FGA']
    tracking_combined_df['DRIVE_PASSES'] = drives_df['DRIVE_PASSES']
    
    #select columns from catch_shoot_df
    tracking_combined_df['CATCH_SHOOT_FGM'] = catch_shoot_df['CATCH_SHOOT_FGM']
    tracking_combined_df['CATCH_SHOOT_FGA'] = catch_shoot_df['CATCH_SHOOT_FGA']
    tracking_combined_df['CATCH_SHOOT_FG3M'] = catch_shoot_df['CATCH_SHOOT_FG3M']
    tracking_combined_df['CATCH_SHOOT_FG3A'] = catch_shoot_df['CATCH_SHOOT_FG3A']
    
    #select columns from catch poss_df
    tracking_combined_df['TOUCHES'] = poss_df['TOUCHES']
    tracking_combined_df['FRONT_CT_TOUCHES'] = poss_df['FRONT_CT_TOUCHES']
    tracking_combined_df['TIME_OF_POSS'] = poss_df['TIME_OF_POSS']
    
    #select columns from pullup_df
    tracking_combined_df['PULL_UP_FGM'] = pullup_df['PULL_UP_FGM']
    tracking_combined_df['PULL_UP_FGA'] = pullup_df['PULL_UP_FGA']
    tracking_combined_df['PULL_UP_FG3M'] = pullup_df['PULL_UP_FG3M']
    tracking_combined_df['PULL_UP_FG3A'] = pullup_df['PULL_UP_FG3A']
    
    #select columns from speed_dist_df
    tracking_combined_df['DIST_MILES'] = speed_dist_df['DIST_MILES']
    tracking_combined_df['DIST_MILES_OFF'] = speed_dist_df['DIST_MILES_OFF']
    tracking_combined_df['DIST_MILES_DEF'] = speed_dist_df['DIST_MILES_DEF']
    
    return tracking_combined_df

# %%
nbatrack_17_18 = create_tracking_dataframes('Regular Season', '2017-18', 'player')
nbatrack_17_18
# Out:
#      PLAYER_ID     PLAYER_NAME     TEAM_ID TEAM_ABBR  DRIVES  DRIVE_FGM  \
# 0       201166    Aaron Brooks  1610612750       MIN      56         12
# 1       203932    Aaron Gordon  1610612753       ORL     301         55
# 2      1626151  Aaron Harrison  1610612742       DAL      22          4
# 3      1628935   Aaron Jackson  1610612745       HOU      10          1
# 4      1627846     Abdel Nader  1610612738       BOS     103         14
# ..         ...             ...         ...       ...     ...        ...
# 535    1628380    Zach Collins  1610612757       POR      50         13
# 536     203897     Zach LaVine  1610612741       CHI     209         47
# 537       2216   Zach Randolph  1610612758       SAC     155         48
# 538       2585   Zaza Pachulia  1610612744       GSW      29          3
# 539    1627753         Zhou Qi  1610612745       HOU      10          1
#
#      DRIVE_FGA  DRIVE_PASSES  CATCH_SHOOT_FGM  CATCH_SHOOT_FGA  ...  TOUCHES  \
# 0           30            18                8               15  ...      404
# 1          145            70              100              265  ...     3476
# 2           11             6                8               37  ...      263
# 3            2             6                0                2  ...       62
# 4           46            30               23               65  ...      626
# ..         ...           ...              ...              ...  ...      ...
# 535         30            11               45              137  ...     1256
# 536        109            60               13               40  ...     1107
# 537         95            29               78              225  ...     3027
# 538         14             7               17               40  ...     1801
# 539          3             4                2               19  ...      147
#
#      FRONT_CT_TOUCHES  TIME_OF_POSS  PULL_UP_FGM  PULL_UP_FGA  PULL_UP_FG3M  \
# 0                 130          35.4           12           31           3.0
# 1                1843         141.2           75          254          23.0
# 2                 159          10.3            5           21           1.0
# 3                  24           4.8            1            2           1.0
# 4                 467          24.1            3           12           1.0
# ..                ...           ...          ...          ...           ...
# 535               790          38.8            6           24           0.0
# 536               688          80.0           49          144          27.0
# 537              2113         104.4           28           81           1.0
# 538              1079          44.4            3            4           0.0
# 539                79           3.7            0            1           0.0
#
#      PULL_UP_FG3A  DIST_MILES  DIST_MILES_OFF  DIST_MILES_DEF
# 0            16.0        13.6             7.3             6.3
# 1           105.0       140.5            78.5            62.0
# 2             6.0        16.6             9.0             7.6
# 3             2.0         2.4             1.2             1.2
# 4             1.0        39.0            20.9            18.1
# ..            ...         ...             ...             ...
# 535           2.0        71.7            38.9            32.8
# 536          74.0        49.9            26.9            23.0
# 537           4.0        99.1            53.2            45.9
# 538           0.0        68.4            34.3            34.1
# 539           0.0         8.6             4.6             4.0
#
# [540 rows x 22 columns]

# %%
import unidecode
#We'll use this module to convert letters with accents or other special characters on letters

# %%
# Out:
# 'testing'

# %%
string = bballref_1718_df.iloc[389]['Player'] 
string
# Out:
# 'Frank Mason III\\masonfr01'

# %%
string.split('\\')[0]
# Out:
# 'Frank Mason III'

# %%
def clean_names(name):
    """This function removes extraneous player IDs from player names collected from Basketball Reference.
       The function removes punctuation from names as name punction is not consistent across different
       sources. The function also removes suffixes from names as suffixes are not consistent across different
       sources. 
       
       The function takes a variable 'name' which should be a string."""
    
    #Name from Basketball Reference will follow the logic in the first if statement
    
    if '\\' in name:
        name_new = name.split('\\')[0]
        if '.' in name_new:
            name_stripped = name_new.replace('.', '') #remove punctuation
        else:
            name_stripped = name_new
    
    #Names from stats.nba.com will follow the logic in the unnested else statement
    
    else:
        name_new = name
        if '.' in name_new:
            name_stripped = name_new.replace('.', '') #remove punctuation
        else:
            name_stripped = name_new
    

    
    name_clean = unidecode.unidecode(name_stripped) #remove accents and special characters
    
    name_split = name_clean.split() #split into first name, last name, and suffix if applicable
    
    name_final = name_split[0] + ' ' + name_split[1] #store only first and last names in variable
    
    return name_final

# %%
clean_names(string)
# Out:
# 'Frank Mason'
