# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
# %matplotlib inline

# %%
df = pd.read_csv('nba_complete_2015-2019.csv')
pd.set_option('max_columns', None)
df.head(20)
# Out:
#                        PLAYER_NAME Pos  Age   Tm   G  GS    MP    FG   FGA  \
# 0               Quincy Acy (15-16)  PF   25  SAC  59  29   876   6.5  11.7
# 1             Jordan Adams (15-16)  SG   21  MEM   2   0    15   6.9  20.6
# 2             Steven Adams (15-16)   C   22  OKC  80  80  2014   6.4  10.5
# 3            Arron Afflalo (15-16)  SG   30  NYK  71  57  2371   7.7  17.3
# 4            Alexis Ajinca (15-16)   C   27  NOP  59  17   861   8.6  18.1
# 5             Cole Aldrich (15-16)   C   27  LAC  60   5   800   8.4  14.1
# 6        LaMarcus Aldridge (15-16)  PF   30  SAS  74  74  2261  12.1  23.7
# 7          Cliff Alexander (15-16)  PF   20  POR   8   0    36   6.9  13.9
# 8              Lavoy Allen (15-16)  PF   26  IND  79  28  1599   5.9  11.5
# 9               Tony Allen (15-16)  SG   34  MEM  64  57  1620   6.8  14.9
# 10         Al-Farouq Aminu (15-16)  SF   25  POR  82  82  2341   6.4  15.4
# ...

# %%
#Dropping duplicate columns ('two_pt_fg_pct' and 'three_pt_fg_pct')
df = df.drop(columns = ['two_pt_fg_pct', 'three_pt_fg_pct'])

# %%
pd.set_option('display.max_rows', None)
df.isna().sum()
# Out:
# PLAYER_NAME            0
# Pos                    0
# Age                    0
# Tm                     0
# G                      0
# GS                     0
# MP                     0
# FG                     0
# FGA                    0
# FG%                    9
# 3P                     0
# 3PA                    0
# 3P%                  164
# 2P                     0
# 2PA                    0
# 2P%                   28
# FT                     0
# FTA                    0
# FT%                   95
# ORB                    0
# DRB                    0
# TRB                    0
# AST                    0
# STL                    0
# BLK                    0
# TOV                    0
# PF                     0
# PTS                    0
# ORtg                   8
# DRtg                   0
# PER                    0
# TS%                    9
# 3PAr                   9
# FTr                    9
# ORB%                   0
# DRB%                   0
# TRB%                   0
# ...

# %%
df.loc[df['DIST_MILES'] == np.nan]
# Out:
# Empty DataFrame
# Columns: [PLAYER_NAME, Pos, Age, Tm, G, GS, MP, FG, FGA, FG%, 3P, 3PA, 3P%, 2P, 2PA, 2P%, FT, FTA, FT%, ORB, DRB, TRB, AST, STL, BLK, TOV, PF, PTS, ORtg, DRtg, PER, TS%, 3PAr, FTr, ORB%, DRB%, TRB%, AST%, STL%, BLK%, TOV%, USG%, OWS, DWS, WS, WS/48, OBPM, DBPM, BPM, VORP, pct_of_FGA_twos, pct_of_FGA_threes, two_pt_fg_pct, three_pt_fg_pct, DRIVES, DRIVE_FGM, DRIVE_FGA, DRIVE_PASSES, CATCH_SHOOT_FGM, CATCH_SHOOT_FGA, CATCH_SHOOT_FG3M, CATCH_SHOOT_FG3A, TOUCHES, FRONT_CT_TOUCHES, TIME_OF_POSS, PULL_UP_FGM, PULL_UP_FGA, PULL_UP_FG3M, PULL_UP_FG3A, DIST_MILES, DIST_MILES_OFF, DIST_MILES_DEF]
# Index: []

# %%
dictionary_list = {'a': 1, 'b': 2, 'c': 3, 'd': np.nan, 'e': 4, 'f': np.nan, 'g': np.nan}
dictionary_list1 = {'a': 1, 'b': 2, 'c': 3, 'd': 8, 'e': 4, 'f': 10, 'g': 14}
dictionary_list2 = {'a': 1, 'b': 2, 'c': 3, 'd': 28, 'e': 4, 'f': 19, 'g': np.nan}
df_dummy = pd.DataFrame([dictionary_list, dictionary_list1, dictionary_list2])
df_dummy
# Out:
#    a  b  c     d  e     f     g
# 0  1  2  3   NaN  4   NaN   NaN
# 1  1  2  3   8.0  4  10.0  14.0
# 2  1  2  3  28.0  4  19.0   NaN

# %%
df_dummy.isna().sum()
# Out:
# a    0
# b    0
# c    0
# d    1
# e    0
# f    1
# g    2
# dtype: int64

# %%
df_dummy.loc[df_dummy['d'] == np.nan]
# Out:
# Empty DataFrame
# Columns: [a, b, c, d, e, f, g]
# Index: []

# %%
type(df.iloc[8]['PULL_UP_FG3M'])
# Out:
# numpy.float64
